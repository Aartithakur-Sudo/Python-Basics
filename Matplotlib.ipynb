# %% [markdown]
# # Matplotlib
#
# - Matplotlib is a low- level graph plotting library in python that serves as a visualization utility and it is a numerical mathematics extension of Numpy
#
# - Its a open source and we can use it freely
#
# - it provides an object oriented API for embedding plots into applications using general purpose GUI toolkits like Tkinter, wxpython , QT or GTK+
#
#        -  Generally easy to get started for simple plots
#        -  Support for custom labels and texts
#        - Great control of evry element in a figure
#        - High-Quality output in many formats
#        - very customizable in general

# %% [markdown]
#      - API- application programming interface
#
#      - GUI - Graphical user interface

# %% [markdown]
# #### %matplotlib inline
# ---  specially if you are working in Jupyter notebook inline is very essential, with the help of it you are able to see the Graphs ,diagrams in this notebook)
# --  if you have not written this line then at the time of plotting a graph or diagram you need to write "plt.show()"

# %%
 import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %% [markdown]
# #### arange
#
#     -  arange is used for basically creating an array and its usually takes the range from(start,stop)

# %%
# Simple Examples
x = np.arange(0,20)
y = np.arange(11,31)

# %% [markdown]
# #### Plotting using Matpotlib
#    - Plot scatter
#           -Scatter plot is basically used to scatter the values of X and Y
#              - plt.scatter%matplotlib inline  (x)
#         Signature:
#       plt.scatter(
#     x,
#     y,
#     s=None, (solid)
#     c=None, (color)
#     marker=None,
#     cmap=None,
#     norm=None,

# %%
plt.scatter(x,y,c='y')

#i need to put some title here xlabel and ylabel are In-built f(x)
plt.xlabel('X axis')
plt.ylabel('Y axis')

#Description of the graph

plt.title('Graph in 2D')
 # if you want to save this image
plt.savefig('Test.png')

# %% [markdown]
# ### Plot
#    -  you'll get a straight line

# %%
y =x*x

# %%
plt.plot(x,y,'c--*')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('2D Graph')
# Out:
# Text(0.5, 1.0, '2D Graph')

# %%
plt.plot(x,y,'c *',linestyle='dashed',linewidth=3,markersize=15)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title("Graph in 2D")
# Out:
# Text(0.5, 1.0, 'Graph in 2D')

# %%
# Creating Subplots
plt.subplot(2,2,1)
plt.plot(x,y,'c')
plt.subplot(2,2,2)
plt.plot(x,y,'r--')
plt.subplot(2,2,3)
plt.plot(x,y,'g--*')
plt.subplot(2,2,4)
plt.plot(x,y,'b*')


#2,2 = 4 so you will only make 4 graphs not more than that

# %%
# we can make it more complex
x = np.arange(1,11)
y = 10*x+29
plt.title("Matplotlib demo")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.plot(x,y)
plt.show()

# %%
np.pi  #22/7
# Out:
# 3.141592653589793

# %%
# compute the x and y coordinaates for points on a sine curve
x = np.arange(0,4*np.pi,0.1)
y =np.sin(x)
plt.title("sine wave form")

#plot the points using matplotlib
plt.plot(x,y)

# %%
#Subplots
# compute the x and y coordinates for points on sine and cosine curves
x = np.arange(0,5*np.pi,0.1)
y_sin = np.sin(x)
y_cos = np.cos(x)

#set up a subplot grid that has height 2 and width 1
# set thte first such subplot as active
plt.subplot(2,1,1)
#make the first plot
plt.plot(x,y_sin,'c-*')
plt.title('Sine')



# set the second subplot as active and make the second plot
plt.subplot(2,1,2)
plt.plot(x,y_cos,'y--',markersize =30)
plt.title('Cosine')

#show the figure
plt.show()

# %% [markdown]
# ### Bar plot

# %%
x = [2,7,9]
y = [11,6,9]

x2 = [3,9,11]
y2 = [6,15,7]
plt.bar(x,y,align ='edge')
plt.bar(x2,y2,color ='c')
plt.title('Bar graph')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.show()

# %% [markdown]
# ### Histograms
#   -  A histogram is an approximate representation of the distribution of numerical data
#
#   - A histogram is a plot that lets you discover, and show, the underlying frequency distribution (shape) of a set of continuous data.
#
#   - Histograms are based on area, not height of bars
#
#            - In a histogram, it is the area of the bar that indicates the
#            frequency of occurrences for each bin. This means that the height of           the bar does not necessarily indicate how many occurrences of scores            there were within each individual bin. It is the product of height/multiplied by the width of the bin that indicates the frequency of       occurrences within that bin. One of the reasons that the height of             the bars is often incorrectly assessed as indicating frequency and              not the area of the bar is due to the fact that a lot of histograms often have equally spaced bars (bins), and under these circumstances, the height of the bin does reflect the frequency.

# %% [markdown]
# #### What is the difference between a bar chart and a histogram?
# The major difference is that a histogram is only used to plot the frequency of score occurrences in a continuous data set that has been divided into classes, called bins. Bar charts, on the other hand, can be used for a great deal of other types of variables including ordinal and nominal data sets.

# %%
a = np.array([22,87,45,67,89,34,46,75,89,67,89,96,36,36,36,36,33,23,45])
plt.hist(a,bins=10)
plt.title("Histogram")    #in x axis we have this (a) values and y axis it will be the count or density 
plt.show()

# %% [markdown]
# ### Boxplot using Matplotlib

# %%
data = [np.random.normal(0, std ,100) for std in range(1,4)]

# rectangular box plot
plt.boxplot(data,vert= True, patch_artist= True);



# these circles are outliers 
# here, vert = true means its vertial presentation ---- vert = true(vertically)    Vert=False(Horizontally)
# patch = false (color will be drained out of the boxes)

# %%
data  #this data is a lsit because here we're using a For loop
# Out:
# [array([ 0.43300789, -1.63885331, -1.42152654, -0.6200919 , -2.85329037,
#          0.39857604,  1.55949404,  0.08301987, -0.7176165 , -0.08383941,
#         -0.98543179, -0.31557532, -2.33005818, -0.75938781, -0.93172024,
#         -1.06391334, -0.70312562, -0.65591534,  1.02726063, -1.06363241,
#         -0.32499184, -0.20763767,  0.99815108, -1.80861669,  0.33067764,
#         -0.06964535,  0.21244503, -0.8569947 , -0.29560755,  1.51422557,
#          0.59850014,  0.08057089,  1.67295411, -1.29473732,  0.92732752,
#          0.89419683,  1.64447684,  0.92103806,  0.36457401, -0.46977945,
#          1.94062004,  1.00915116,  1.07610093,  0.78734001,  1.79636922,
#          0.39037866,  0.4428966 ,  1.24450396,  0.25724186, -0.70149445,
#          1.88749203,  1.46631658,  2.18877538, -0.58722161, -1.13294799,
#          1.56722084, -0.13434673, -0.85259228, -1.0272695 , -0.35370408,
#          1.31398638, -2.34633353,  0.65800142, -1.98878975,  0.33632843,
# ...

# %% [markdown]
# ### Pie Chart

# %%
#Data to Plot

labels = 'python', 'C++','Ruby','Java'
Sizes = [215,130,245,210]
colors = ['gold','yellowgreen','lightcoral','lightskyblue']
#explode 1st slide
explode =(0.1,0,0,0)

#plot
plt.pie(Sizes, explode=explode,labels=labels,colors=colors,autopct='%1.1f%%',shadow = True)

plt.axis('equal')
plt.show()
