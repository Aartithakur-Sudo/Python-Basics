# %% [markdown]
# ### New York City Airbnb Open Data

# %%
from IPython.display import Image
Image(filename='airbnb.jpeg')

# %% [markdown]
# #### import the libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Read the data

# %%
df = pd.read_csv('AB_NYC_2019.csv')
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.shape
# Out:
# (48895, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Check the missing values

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# There are missing values in name, host_name,last_review,reviews_per_month, we need to handle these values

# %% [markdown]
# Missing values visualization

# %%
import missingno as msno

# %%
msno.matrix(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Checking the correlation between any values

# %%
msno.heatmap(df)
# Out:
# <AxesSubplot:>

# %%
msno.bar(df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Drop the missing values in name,host_name column

# %%
df = df[~df.name.isnull()].copy()
df = df[~df.host_name.isnull()].copy()
#chcek the  missing values in the dataset
df.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10037
# reviews_per_month                 10037
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %% [markdown]
# dropping the column which are irrelevant like the last_review, host_name and dropping the id as well as i dont need them for the EDA part and replacing the Nan values in review_per_month  will 0

# %%
df.drop(['id','last_review'], axis =1, inplace = True)

# %%
#replacing the values
df.fillna({'reviews_per_month': 0}, inplace = True)

# %%
df.head(3)
# Out:
#                                   name  host_id  host_name  \
# 0   Clean & quiet apt home by the park     2787       John
# 1                Skylit Midtown Castle     2845   Jennifer
# 2  THE VILLAGE OF HARLEM....NEW YORK !     4632  Elisabeth
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0    149               1                  9               0.21
# 1    225               1                 45               0.38
# 2    150               3                  0               0.00
#
#    calculated_host_listings_count  availability_365
# 0                               6               365
# 1                               2               355
# ...

# %%
df.corr()
# Out:
#                                  host_id  latitude  longitude     price  \
# host_id                         1.000000  0.020224   0.127055  0.015309
# latitude                        0.020224  1.000000   0.084788  0.033939
# longitude                       0.127055  0.084788   1.000000 -0.150019
# price                           0.015309  0.033939  -0.150019  1.000000
# minimum_nights                 -0.017364  0.024869  -0.062747  0.042799
# number_of_reviews              -0.140106 -0.015389   0.059094 -0.047954
# reviews_per_month               0.209783 -0.018758   0.138516 -0.050564
# calculated_host_listings_count  0.154950  0.019517  -0.114713  0.057472
# availability_365                0.203492 -0.010983   0.082731  0.081829
#
#                                 minimum_nights  number_of_reviews  \
# host_id                              -0.017364          -0.140106
# latitude                              0.024869          -0.015389
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   name                            48879 non-null  object
#  1   host_id                         48895 non-null  int64
#  2   host_name                       48874 non-null  object
#  3   neighbourhood_group             48895 non-null  object
#  4   neighbourhood                   48895 non-null  object
#  5   latitude                        48895 non-null  float64
#  6   longitude                       48895 non-null  float64
#  7   room_type                       48895 non-null  object
#  8   price                           48895 non-null  int64
#  9   minimum_nights                  48895 non-null  int64
#  10  number_of_reviews               48895 non-null  int64
#  11  reviews_per_month               48895 non-null  float64
# ...

# %% [markdown]
# describe the data

# %%
df.describe()
# Out:
#             host_id      latitude     longitude         price  minimum_nights  \
# count  4.889500e+04  48895.000000  48895.000000  48895.000000    48895.000000
# mean   6.762001e+07     40.728949    -73.952170    152.720687        7.029962
# std    7.861097e+07      0.054530      0.046157    240.154170       20.510550
# min    2.438000e+03     40.499790    -74.244420      0.000000        1.000000
# 25%    7.822033e+06     40.690100    -73.983070     69.000000        1.000000
# 50%    3.079382e+07     40.723070    -73.955680    106.000000        3.000000
# 75%    1.074344e+08     40.763115    -73.936275    175.000000        5.000000
# max    2.743213e+08     40.913060    -73.712990  10000.000000     1250.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       48895.000000       48895.000000                    48895.000000
# mean           23.274466           1.090910                        7.143982
# ...

# %% [markdown]
# Describe the price

# %%
df.price.describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %% [markdown]
# here, we can see that the mean value of price is 152 , and 75% of price value is 175 but there's one outlier that is the max value is 10000

# %% [markdown]
# Boxplot

# %%
plt.boxplot(df.price)
fig = plt.figure(figsize=(10,7))
plt.show()

# %% [markdown]
# so from above figure, we can witness the outliers in our upper whisker

# %%
corr = df.corr()
sns.heatmap(corr, xticklabels = corr.columns,
           yticklabels= corr.columns, annot = True)
fig = plt.figure(figsize=(20,20))

# %% [markdown]
# Here upon looking into the matrix , we can see that the variable are not that strongly related

# %% [markdown]
# #### Which hosts are the busiest and why?

# %%
#it shows the top hosts of newyork city using Airbnb
top_host = df.host_name.value_counts().head(10)
top_host
# Out:
# Michael         417
# David           403
# Sonder (NYC)    327
# John            294
# Alex            279
# Blueground      232
# Sarah           227
# Daniel          226
# Jessica         205
# Maria           204
# Name: host_name, dtype: int64

# %%
df.calculated_host_listings_count.max()
# Out:
# 327

# %% [markdown]
# Neighbourhood

# %%
#Lets check the neighbourhood prices
df.neighbourhood_group.unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
#we can see that there are some extreme values in pricw so we would be taking till 600

price_range = df[df.price<600]

# %%
fig, ax = plt.subplots(figsize = (12,6))
fig.patch.set_facecolor('#f6f5f7')
ax.set_facecolor('#f6f5f5')

plt_2=sns.violinplot(x='neighbourhood_group',y='price', data= price_range,palette='winter')
plt_2.set_title('prices wrt different regions');

# %% [markdown]
# Most of the listings in different regions lay under $100

# %% [markdown]
# Room Types

# %%
df.room_type.unique()
# Out:
# array(['Private room', 'Entire home/apt', 'Shared room'], dtype=object)

# %%
nbd_room_type = df.groupby(['neighbourhood_group'])['room_type'].value_counts().unstack(0)

# %%
nbd_room_type
# Out:
# neighbourhood_group  Bronx  Brooklyn  Manhattan  Queens  Staten Island
# room_type
# Entire home/apt        379      9559      13199    2096            176
# Private room           652     10132       7982    3372            188
# Shared room             60       413        480     198              9

# %% [markdown]
# Different room types in various regions
